# %% [markdown]
# # Филогенетический анализ белков семейства Ly6/uPAR

# %%
from Bio import Phylo, AlignIO
from Bio.Phylo.TreeConstruction import DistanceCalculator, DistanceTreeConstructor
import matplotlib
import matplotlib.pyplot as plt

# %%
align = 'input/align_upar.aln'
with open(align) as f:
    alignment = AlignIO.read(f, 'fasta')

calculator = DistanceCalculator('identity')
constructor = DistanceTreeConstructor(calculator, 'upgma')
ly6_tree = constructor.build_tree(alignment)
ly6_tree.rooted = False
# print(turtle_tree)

# %%
def remove_inner(tree):
    for i in tree.get_nonterminals():
        i.name = None

# %%
remove_inner(ly6_tree)

fig = plt.figure(figsize=(25, 50), dpi=300)
matplotlib.rc('font', size=12)
matplotlib.rc('xtick', labelsize=10)
matplotlib.rc('ytick', labelsize=10)
ly6_tree.ladderize()

axes = fig.add_subplot(1, 1, 1)
Phylo.draw(ly6_tree, axes=axes)
plt.tight_layout()
fig.savefig("Ly6_uPAR_clad")

# %%
res_tree = "results/ly6_tree.nex"
Phylo.write(ly6_tree, res_tree, "nexus")
ly6_tree = Phylo.read(res_tree, "nexus")

# %% [raw]
# awk -F , '{print ">"$1"\n"$2}' input/ly6upar.csv > ly6upar.fasta
# clustalo -i ly6upar.fasta -o align_upar.aln --threads=4
